# %%
import pandas as pd
import numpy as no
import matplotlib.pyplot as plt
# %pylab inline
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train = pd.read_csv('../data/train/train.csv', encoding="ISO-8859-1")
test = pd.read_csv('../data/test/test.csv', encoding="ISO-8859-1")
descr = pd.read_csv('../data/train/product_descriptions.csv')
attr = pd.read_csv('../data/train/attributes.csv')
train_size = train.shape[0]
test_size = test.shape[0]
print ("train_size", train_size)
print ("test_size", test_size)
# Out:
# ('train_size', 74067)
# ('test_size', 166693)

# %%
train.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1   3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2   9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3  16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4  17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
#
#           search_term  relevance
# 0       angle bracket       3.00
# 1           l bracket       2.50
# 2           deck over       3.00
# 3    rain shower head       2.33
# 4  shower only faucet       2.67

# %%
test.head()
# Out:
#    id  product_uid                      product_title  \
# 0   1       100001  Simpson Strong-Tie 12-Gauge Angle
# 1   4       100001  Simpson Strong-Tie 12-Gauge Angle
# 2   5       100001  Simpson Strong-Tie 12-Gauge Angle
# 3   6       100001  Simpson Strong-Tie 12-Gauge Angle
# 4   7       100001  Simpson Strong-Tie 12-Gauge Angle
#
#                  search_term
# 0          90 degree bracket
# 1           metal l brackets
# 2           simpson sku able
# 3       simpson strong  ties
# 4  simpson strong tie hcc668

# %%
descr.head()
# Out:
#    product_uid                                product_description
# 0       100001  Not only do angles make joints stronger, they ...
# 1       100002  BEHR Premium Textured DECKOVER is an innovativ...
# 2       100003  Classic architecture meets contemporary design...
# 3       100004  The Grape Solar 265-Watt Polycrystalline PV So...
# 4       100005  Update your bathroom with the Delta Vero Singl...

# %%
attr.head()
# Out:
#    product_uid      name                                              value
# 0       100001  Bullet01  Versatile connector for various 90° connection...
# 1       100001  Bullet02  Stronger than angled nailing or screw fastenin...
# 2       100001  Bullet03  Help ensure joints are consistently straight a...
# 3       100001  Bullet04              Dimensions: 3 in. x 3 in. x 1-1/2 in.
# 4       100001  Bullet05                           Made from 12-Gauge steel

# %%
attr.name.value_counts(normalize=True)[:10]
# Out:
# MFG Brand Name          0.042180
# Bullet02                0.042179
# Bullet03                0.042168
# Bullet04                0.042143
# Bullet01                0.042028
# Product Width (in.)     0.029899
# Bullet05                0.029601
# Product Height (in.)    0.026750
# Product Depth (in.)     0.026238
# Product Weight (lb.)    0.022093
# Name: name, dtype: float64

# %% [markdown]
# ## Since raters didn't have access to the attributes, let's set this dataset aside for now

# %%
train = pd.merge(train, descr, how='left', on='product_uid')
test = pd.merge(test, descr, how='left', on='product_uid')

# %%
train.describe()
# Out:
#                   id    product_uid     relevance
# count   74067.000000   74067.000000  74067.000000
# mean   112385.709223  142331.911553      2.381634
# std     64016.573650   30770.774864      0.533984
# min         2.000000  100001.000000      1.000000
# 25%     57163.500000  115128.500000      2.000000
# 50%    113228.000000  137334.000000      2.330000
# 75%    168275.500000  166883.500000      3.000000
# max    221473.000000  206650.000000      3.000000

# %%
train.relevance.hist(bins=20, normed=True);

# %% [markdown]
# ## Only ~16% of rates are lower than 2 (worse than "relevant"). ~58% are between 2 and 3. 26% are pefect matches (3.0)

# %%
train.relevance.value_counts(normalize=True)
# Out:
# 3.00    0.258212
# 2.33    0.216831
# 2.67    0.205247
# 2.00    0.158370
# 1.67    0.091539
# 1.33    0.040585
# 1.00    0.028420
# 2.50    0.000257
# 2.25    0.000149
# 2.75    0.000149
# 1.75    0.000122
# 1.50    0.000068
# 1.25    0.000054
# Name: relevance, dtype: float64

# %% [markdown]
# ## It seems that raters gave integer rates, and there were 3 or 4 raters for each row

# %%
for col in train.drop(['id', 'product_uid', 'relevance'], axis=1).columns:
    print(col)
    print(train[col].value_counts(normalize=False)[:3])
# Out:
# product_title
# Lithonia Lighting All Season 4 ft. 2-Light Grey T8 Strip Fluorescent Shop Light                                          21
# Pressure-Treated Timber #2 Southern Yellow Pine (Common: 4 in. x 4 in. x 8 ft.; Actual: 3.56 in. x 3.56 in. x 96 in.)    21
# 2 in. x 4 in. x 96 in. Premium Kiln-Dried Whitewood Stud                                                                 18
# Name: product_title, dtype: int64
# search_term
# bed frames headboaed                      16
# contact paoer                             16
# moen chat oil bronze tub/shower faucet    16
# Name: search_term, dtype: int64
# product_description
# Ready to assemble means you save with Heartland Cabinetry.  Heartland Cabinets are shipped to you unassembled.  Each cabinet comes with simple assembly and installation instructions that require only standard household tools.  Make your home a special place for everyday living.  Heartland Cabinetry captures the classic style and grace that creates a charming setting for any gathering.  Items take time to assemble, but will withstand years of use.  Two people are suggested for proper assembly.EZ hang system simplifies installation by supporting wall cabinets while they are secured in placeFully-reversible door mounts on left or rightAdjustable full-depth wall shelves allow for maximum storageSelf-locking shelf clips prevent shelves from tippingConstructed of sturdy engineered woodQuick and easy metal cam and glue dowel assemblyInterior cabinet surfaces, including shelves, highly water resistant6 way adjustable concealed door hingesFinished toe kick base cabinetsDeep, full extension drawersEasy clean thermofoil white and cherry color door stylesOpen access frameless constructionFull overlay cabinet door design at a low price5 year manufactures warrantyHeartland cabinets require assembly upon delivery                                                                                            36
# Team spirit by the gallon. With the officially licensed colors from your favorite teams, you can turn any room into your dream "Fan Cave". Don't worry about your paint's defense either. Glidden's DUO formula is more than just a paint. It also primes with every single roll, saving you time and energy. Better yet, Glidden DUO Paint and Primer is a great value. You only have to purchase one product to get a quality primer plus a premium paint. Glidden DUO Paint and Primer is available in three sheens and 282 interior colors and is especially effective as a bathroom paint. Get going on your project today to experience beautiful, long-lasting results, guaranteed.California residents: see&nbsp;Proposition 65 informationExceptional hiding power for great coverage in fewer coats, even over darker colorsExcellent adhesion to most new or previously painted surfacesStain-blocking primer combined with stain-resistant paintMildew-resistant coating that's great for bathroomsEasy cleaning to keep walls looking good over timeLow odor and low VOCsActual paint colors may vary from on-screen and printer representationsOnline Price includes Paint Care fee in the following states: CA, CO, CT, MN, OR, RI, VTClick here to use our paint calculator and estimate how much paint you need to complete your project    31
# Protect your outdoor items from winter's wrath with our line of Hearth & Garden Patio Furniture Covers. Made from high grade Polyester, our furniture covers resist cracking, fading, tearing, and mold build up. The underside is coated with PVC for increased water resistance and further protection from the elements. You can be confident that your patio furniture is secure through the seasons. We have covers available to fit all of your needs, from tables and chairs to grills and patio heaters. You've invested a lot in your patio furniture and you should protect it with the best.Heavyweight fabric resists ripping and tearingCoated underside provides added water protectionSynthetic material resists mold and mildew buildupMaterial breaths allowing heat and moisture to escapeHighly weather resistant limiting potential for cracking in cold weatherNeutral but fashionable taupe color matches your outdoor furniture and environment                                                                                                                                                                                                                                                                                                                                                                                       26
# Name: product_description, dtype: int64

# %%
train['search_term'].value_counts(normalize=True)[:10]
# Out:
# bed frames headboaed                           0.000216
# contact paoer                                  0.000216
# moen chat oil bronze tub/shower faucet         0.000216
# 1/2 zip wall                                   0.000216
# burgundy red foot stools                       0.000216
# 3 WAY TOGGLE SWITCH                            0.000216
# metal sheet                                    0.000216
# anderson windows 400 seriesimpact resistant    0.000216
# everblit heavy duty canvas dropcloth           0.000216
# halloween light                                0.000203
# Name: search_term, dtype: float64

# %%
test['search_term'].value_counts(normalize=True)[:10]
# Out:
# patio chair cushions    0.000216
# gravel                  0.000138
# closet light            0.000138
# gas furnace             0.000138
# chaise lounge           0.000138
# patio umbrella          0.000138
# concrete resurfacer     0.000138
# pendant light           0.000138
# pliers                  0.000138
# speaker wire            0.000138
# Name: search_term, dtype: float64

# %% [markdown]
# ## Search terms are just a few words. Product titles are longer and include many numbers. Product descriptions contain several lines

# %%
predictors = ['search_term', 'product_title', 'product_description']
fig, ax = plt.subplots(figsize=(20,20), nrows=len(predictors), ncols=2)
for i, feat in enumerate(predictors):
    for j, df in enumerate([train, test]):
        ax[i][j].hist(df[feat].apply(lambda x: len(x.split())), normed=True, bins=20)
        ax[i][j].set_xlabel(feat + ' length')
        ax[i][0].set_title('train')
        ax[i][1].set_title('test')

# %% [markdown]
# ## The distribution of lenghts is similar in both train and test sets

# %%
for df in [train, test]:
    print(df[df.isnull().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [id, product_uid, product_title, search_term, relevance, product_description]
# Index: []
# Empty DataFrame
# Columns: [id, product_uid, product_title, search_term, product_description]
# Index: []

# %% [markdown]
# ## No missing values!!

# %% [markdown]
# ## Let's make columns with the length of query, title, and description. And other columns with the number of common words between the query (search_term) and the title and description. Before and after steming (exact and approximate matches)

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

stop = set(stopwords.words('english'))
porter = PorterStemmer()
# stemmers = [('porter', PorterStemmer), 
#         ('snowball', SnowballStemmer('english')), 
#         ('wordnet', WordNetLemmatizer)]
#train, test = train.copy(), test.copy()
predictors = ['search_term', 'product_title', 'product_description']
first_pred = predictors

def feature_extractor(train, test):

    for df in [train, test]: 
        for col in first_pred:

            df[col + '_length'] = df[col].apply(lambda x: len(x.split()) * 1.)

            df['tokenized_' + col] = df[col].apply(lambda x: word_tokenize(x.lower()))

            df['tokenized_' + col] = [[token for token in tokens if token not in stop] # we might want to include words                                          
                                            for tokens in df['tokenized_' + col]]  # like over, which are stop words
            
            df['stemized_' + col] = [[porter.stem(word) for word in words] for words in df['tokenized_'+col]]


        for col in first_pred:
            if col != 'search_term':
                a = zip(df['tokenized_search_term'], df['tokenized_' + col])
                df[col + '_query_exactmatch'] = [len(set(i) & set(j)) * 1. for i, j in a]  

                a = zip(df['stemized_search_term'], df['stemized_' + col])
                df[col + '_query_match'] = [len(set(i) & set(j)) * 1. for i, j in a]  

        for col in first_pred:
            df['stemized_' + col] = df['stemized_' + col].apply(lambda x: ' '.join(x))

#     tfidf = TfidfVectorizer(ngram_range=(1, 1), max_features=100)
#     tfidf.fit(train.stemized_search_term)

    return train, test

# %%
df_tr, df_test = feature_extractor(train, test)

# %% [markdown]
# ## Let's make  a tf-idf bag of words from the search_term feature. We will only keep the 100 most commond 1-grams and 2-grams across all search_term queries. In this particular case (search_terms containing few words), those 100 words should be nearly the same as those with the lowest idf, as I don't expect queries containing the same word more than once, except errors.
#
# ## Note we are using the log(1+term freq) rather than term frequency itself.

# %%
from sklearn.feature_extraction.text import  TfidfVectorizer
from collections import defaultdict

def bag_words(train, test):
    
        
    tfidf = TfidfVectorizer(ngram_range=(1, 2), token_pattern='(?u)\\b\\w\w+\\b', min_df=10, max_features=100, stop_words='english', 
                            lowercase=True, sublinear_tf=True, smooth_idf=True)
    tr_bag = tfidf.fit_transform(train.stemized_search_term)
    test_bag = tfidf.transform(test.stemized_search_term)
     
    # inverse document frequency = tfidf.idf_ 
    # sort columns in bag of words according to idf
    indices = np.argsort(tfidf.idf_)
    terms = tfidf.get_feature_names()
    terms = [terms[i] for i in indices]
    tr_bag = tr_bag[:,indices].todense()
    test_bag = test_bag[:,indices].todense()
    print("terms with the lowest idf: ", terms[:5])
    
    predictors = ['id', 'search_term_length', 'product_title_length', 'product_description_length',
                'product_title_query_exactmatch', 'product_title_query_match', 
                'product_description_query_exactmatch', 'product_description_query_match']
    train = train.loc[:,predictors]
    test = test.loc[:,predictors]
    
    tr_bag = pd.DataFrame(data=tr_bag, columns=terms, index=train['id'])
    train = pd.merge(train, tr_bag, how='left',left_on='id', right_index=True)
    
    test_bag = pd.DataFrame(data=test_bag, columns=terms, index=test['id'])
    test = pd.merge(test, test_bag, how='left', left_on='id', right_index=True)

    return train, test

# %%
train, test = bag_words(df_tr, df_test)
# Out:
# ('terms with the lowest idf: ', [u'door', u'light', u'tile', u'inch', u'wall'])

# %%
train['door'].value_counts(normalize=True).iloc[:5]
# Out:
# 0.000000    0.951328
# 1.000000    0.017646
# 0.538678    0.002660
# 0.632127    0.002052
# 0.539165    0.001917
# Name: door, dtype: float64

# %% [markdown]
# ## ['door', 'light', 'tile', 'inch', 'wall'] are the most common terms in queries. 5% of the queries contain the word door

# %%
[col for col in train.columns if len(col.split())>1]
# Out:
# [u'water heater']

# %% [markdown]
# ## There's only one 2-gram ('water heater') among the most frequent search_terms

# %%
train.describe()
# Out:
#                   id  search_term_length  product_title_length  \
# count   74067.000000        74067.000000          74067.000000
# mean   112385.709223            3.159207             11.566393
# std     64016.573650            1.262096              4.272845
# min         2.000000            1.000000              1.000000
# 25%     57163.500000            2.000000              8.000000
# 50%    113228.000000            3.000000             11.000000
# 75%    168275.500000            4.000000             14.000000
# max    221473.000000           14.000000             35.000000
#
#        product_description_length  product_title_query_exactmatch  \
# count                74067.000000                    74067.000000
# mean                   133.725667                        1.540335
# std                     77.113082                        1.084788
# min                     21.000000                        0.000000
# 25%                     80.000000                        1.000000
# 50%                    114.000000                        2.000000
# 75%                    165.000000                        2.000000
# max                    857.000000                       10.000000
#
#        product_title_query_match  product_description_query_exactmatch  \
# count               74067.000000                          74067.000000
# mean                    1.739682                              1.481375
# std                     1.078294                              1.066505
# min                     0.000000                              0.000000
# 25%                     1.000000                              1.000000
# 50%                     2.000000                              1.000000
# 75%                     2.000000                              2.000000
# max                    10.000000                              9.000000
#
#        product_description_query_match          door         light  \
# count                     74067.000000  74067.000000  74067.000000
# mean                          1.678750      0.033984      0.035990
# std                           1.066816      0.158939      0.168142
# min                           0.000000      0.000000      0.000000
# 25%                           1.000000      0.000000      0.000000
# 50%                           2.000000      0.000000      0.000000
# 75%                           2.000000      0.000000      0.000000
# max                          10.000000      1.000000      1.000000
#
#            ...              stove         garag         mower        garden  \
# count      ...       74067.000000  74067.000000  74067.000000  74067.000000
# mean       ...           0.003950      0.004129      0.004565      0.004334
# std        ...           0.056765      0.058662      0.065045      0.062068
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.000000      0.000000      0.000000      0.000000
# 50%        ...           0.000000      0.000000      0.000000      0.000000
# 75%        ...           0.000000      0.000000      0.000000      0.000000
# max        ...           1.000000      1.000000      1.000000      1.000000
#
#                  ge        closet  water heater          tree            36  \
# count  74067.000000  74067.000000  74067.000000  74067.000000  74067.000000
# mean       0.004152      0.004106      0.002867      0.004624      0.003351
# std        0.060080      0.059403      0.041148      0.066866      0.049764
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      0.635856      1.000000      1.000000
#
#                  20
# count  74067.000000
# mean       0.003605
# std        0.054135
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 108 columns]

# %%
# we dropped relevance above. Let's insert it at the beginning
train.insert(0, 'relevance', df_tr.relevance)

# %%
train.corr(method='pearson')
# Out:
#                                       relevance        id  search_term_length  \
# relevance                              1.000000 -0.116426           -0.072279
# id                                    -0.116426  1.000000            0.192900
# search_term_length                    -0.072279  0.192900            1.000000
# product_title_length                  -0.018810  0.044192            0.145657
# product_description_length             0.039927 -0.072650            0.059321
# product_title_query_exactmatch         0.207945  0.151097            0.476029
# product_title_query_match              0.238750  0.161848            0.496420
# product_description_query_exactmatch   0.187918  0.050415            0.458113
# product_description_query_match        0.208070  0.049504            0.481139
# door                                   0.006027 -0.005330            0.091614
# light                                  0.031087  0.004579            0.052072
# tile                                   0.021739 -0.026169            0.025578
# inch                                  -0.022509  0.009487            0.143559
# wall                                   0.003483  0.008761            0.059765
# cabinet                                0.015879 -0.001177            0.043329
# shower                                 0.022609  0.013314            0.079515
# wood                                  -0.022073  0.007075            0.020751
# white                                  0.006818  0.032681            0.083730
# paint                                 -0.001751  0.034112            0.025517
# floor                                  0.001623 -0.005168            0.038390
# vaniti                                 0.033169  0.005345            0.065899
# outdoor                                0.013693  0.007272            0.018344
# water                                 -0.009998 -0.012152            0.039169
# sink                                   0.034784  0.005626            0.067690
# bathroom                               0.019128 -0.022291            0.056971
# faucet                                 0.027652  0.017144            0.056432
# kitchen                                0.003360 -0.010792            0.067191
# electr                                 0.002376 -0.004798            0.036399
# kit                                   -0.009821  0.007666            0.041960
# ga                                     0.008305 -0.033074            0.028836
# ...                                         ...       ...                 ...
# stainless                              0.008866  0.019508            0.066685
# rug                                    0.016590  0.026976            0.016237
# stone                                  0.001196 -0.000371           -0.007444
# spray                                  0.008080  0.026628            0.018904
# bath                                   0.013099 -0.011333            0.012452
# 30                                     0.004587  0.010125            0.064890
# plate                                  0.002681  0.022871            0.019794
# exterior                               0.010655  0.001335            0.031456
# bolt                                  -0.000434  0.013863            0.025981
# hose                                  -0.012497  0.006869            0.025597
# doubl                                  0.012805  0.005030            0.052427
# handl                                 -0.004797  0.021833            0.042340
# lock                                   0.000047  0.019017            0.002794
# bar                                   -0.002599  0.019983            0.027605
# trim                                  -0.012600  0.012218            0.016369
# valv                                   0.003269  0.019720            0.023427
# blade                                  0.004099  0.004299            0.032050
# screen                                -0.017939 -0.007890           -0.003561
# dewalt                                 0.030894 -0.024195            0.009887
# interior                               0.006802 -0.005940            0.053260
# stove                                 -0.013929 -0.018257            0.000782
# garag                                 -0.005718 -0.016204            0.038640
# mower                                  0.006583 -0.029024            0.015883
# garden                                -0.007671  0.008327           -0.011872
# ge                                     0.009849 -0.000207            0.030338
# closet                                 0.000464 -0.015678            0.022427
# water heater                           0.021625 -0.036214            0.067411
# tree                                   0.001924  0.005757            0.008753
# 36                                     0.003923  0.003819            0.081591
# 20                                    -0.010498  0.009468            0.073324
#
#                                       product_title_length  \
# relevance                                        -0.018810
# id                                                0.044192
# search_term_length                                0.145657
# product_title_length                              1.000000
# product_description_length                        0.283225
# product_title_query_exactmatch                    0.198780
# product_title_query_match                         0.213936
# product_description_query_exactmatch              0.107605
# product_description_query_match                   0.103353
# door                                              0.082126
# light                                            -0.051798
# tile                                              0.157355
# inch                                              0.053060
# wall                                              0.025557
# cabinet                                           0.034057
# shower                                            0.075972
# wood                                              0.057690
# white                                             0.050181
# paint                                            -0.046089
# floor                                             0.121138
# vaniti                                            0.127564
# outdoor                                          -0.020656
# water                                            -0.006119
# sink                                              0.044824
# bathroom                                          0.037375
# faucet                                            0.027887
# kitchen                                           0.018757
# electr                                           -0.016885
# kit                                              -0.016076
# ga                                               -0.000126
# ...                                                    ...
# stainless                                         0.026304
# rug                                               0.036166
# stone                                             0.049636
# spray                                            -0.011012
# bath                                              0.021412
# 30                                                0.030511
# plate                                            -0.020132
# exterior                                          0.019200
# bolt                                              0.002993
# hose                                             -0.024148
# doubl                                             0.039016
# handl                                            -0.009788
# lock                                             -0.026196
# bar                                               0.003615
# trim                                              0.045129
# valv                                              0.014811
# blade                                            -0.022538
# screen                                            0.005549
# dewalt                                           -0.048455
# interior                                          0.004590
# stove                                            -0.007266
# garag                                            -0.001120
# mower                                            -0.005114
# garden                                           -0.012042
# ge                                               -0.004307
# closet                                           -0.010760
# water heater                                      0.031269
# tree                                              0.008845
# 36                                                0.041767
# 20                                               -0.001467
#
#                                       product_description_length  \
# relevance                                               0.039927
# id                                                     -0.072650
# search_term_length                                      0.059321
# product_title_length                                    0.283225
# product_description_length                              1.000000
# product_title_query_exactmatch                          0.081343
# product_title_query_match                               0.070232
# product_description_query_exactmatch                    0.158314
# product_description_query_match                         0.138841
# door                                                    0.063563
# light                                                  -0.042945
# tile                                                    0.131156
# inch                                                    0.006108
# wall                                                    0.005250
# cabinet                                                -0.024611
# shower                                                 -0.022582
# wood                                                    0.000186
# white                                                   0.012503
# paint                                                   0.004126
# floor                                                   0.053374
# vaniti                                                  0.024549
# outdoor                                                -0.001658
# water                                                   0.034999
# sink                                                   -0.005318
# bathroom                                               -0.006236
# faucet                                                 -0.010549
# kitchen                                                 0.001237
# electr                                                  0.040207
# kit                                                    -0.003346
# ga                                                      0.071303
# ...                                                          ...
# stainless                                               0.037353
# rug                                                     0.020321
# stone                                                   0.034309
# spray                                                  -0.002638
# bath                                                   -0.009639
# 30                                                      0.042967
# plate                                                  -0.048151
# exterior                                                0.001932
# bolt                                                   -0.040572
# hose                                                   -0.029672
# doubl                                                   0.024735
# handl                                                  -0.025643
# lock                                                   -0.020345
# bar                                                    -0.032067
# trim                                                   -0.007961
# valv                                                   -0.003896
# blade                                                  -0.031211
# screen                                                 -0.006436
# dewalt                                                  0.003505
# interior                                                0.006485
# stove                                                   0.053052
# garag                                                   0.013200
# mower                                                   0.055985
# garden                                                 -0.004780
# ge                                                      0.083180
# closet                                                 -0.009351
# water heater                                            0.070999
# tree                                                   -0.012337
# 36                                                      0.027100
# 20                                                      0.010842
#
#                                       product_title_query_exactmatch  \
# relevance                                                   0.207945
# id                                                          0.151097
# search_term_length                                          0.476029
# product_title_length                                        0.198780
# product_description_length                                  0.081343
# product_title_query_exactmatch                              1.000000
# product_title_query_match                                   0.924486
# product_description_query_exactmatch                        0.665800
# product_description_query_match                             0.614469
# door                                                        0.065065
# light                                                       0.026471
# tile                                                        0.049176
# inch                                                        0.029555
# wall                                                        0.040671
# cabinet                                                     0.014472
# shower                                                      0.079259
# wood                                                        0.002619
# white                                                       0.103962
# paint                                                       0.025739
# floor                                                       0.030171
# vaniti                                                      0.077596
# outdoor                                                     0.006240
# water                                                       0.039791
# sink                                                        0.061618
# bathroom                                                    0.012748
# faucet                                                      0.079645
# kitchen                                                     0.032447
# electr                                                      0.017655
# kit                                                         0.029158
# ga                                                          0.038112
# ...                                                              ...
# stainless                                                   0.096403
# rug                                                         0.015079
# stone                                                      -0.003483
# spray                                                       0.032205
# bath                                                       -0.000905
# 30                                                          0.056885
# plate                                                       0.015404
# exterior                                                    0.002840
# bolt                                                        0.017243
# hose                                                        0.001055
# doubl                                                       0.050771
# handl                                                       0.015225
# lock                                                       -0.013709
# bar                                                         0.035036
# trim                                                        0.014482
# valv                                                        0.026343
# blade                                                       0.020345
# screen                                                     -0.006809
# dewalt                                                      0.014209
# interior                                                    0.026588
# stove                                                      -0.017504
# garag                                                       0.009693
# mower                                                       0.005767
# garden                                                      0.002149
# ge                                                          0.057023
# closet                                                     -0.013832
# water heater                                                0.095623
# tree                                                        0.012806
# 36                                                          0.052201
# 20                                                          0.021598
#
#                                       product_title_query_match  \
# relevance                                              0.238750
# id                                                     0.161848
# search_term_length                                     0.496420
# product_title_length                                   0.213936
# product_description_length                             0.070232
# product_title_query_exactmatch                         0.924486
# product_title_query_match                              1.000000
# product_description_query_exactmatch                   0.647556
# product_description_query_match                        0.673782
# door                                                   0.089693
# light                                                  0.058904
# tile                                                   0.050282
# inch                                                   0.021288
# wall                                                   0.038948
# cabinet                                                0.043687
# shower                                                 0.076757
# wood                                                   0.002577
# white                                                  0.100444
# paint                                                  0.020416
# floor                                                  0.039673
# vaniti                                                 0.076589
# outdoor                                                0.014217
# water                                                  0.040795
# sink                                                   0.068957
# bathroom                                               0.017332
# faucet                                                 0.083050
# kitchen                                                0.042922
# electr                                                 0.017718
# kit                                                    0.032156
# ga                                                     0.039335
# ...                                                         ...
# stainless                                              0.098886
# rug                                                    0.033115
# stone                                                  0.000621
# spray                                                  0.025753
# bath                                                  -0.000786
# 30                                                     0.046012
# plate                                                  0.028160
# exterior                                               0.008154
# bolt                                                   0.030591
# hose                                                  -0.002563
# doubl                                                  0.050885
# handl                                                  0.018217
# lock                                                  -0.005311
# bar                                                    0.036692
# trim                                                   0.013913
# valv                                                   0.027898
# blade                                                  0.033048
# screen                                                 0.002564
# dewalt                                                 0.005960
# interior                                               0.038034
# stove                                                 -0.027274
# garag                                                  0.017762
# mower                                                  0.009224
# garden                                                 0.003578
# ge                                                     0.048861
# closet                                                -0.003097
# water heater                                           0.098996
# tree                                                   0.018761
# 36                                                     0.051883
# 20                                                     0.020814
#
#                                       product_description_query_exactmatch  \
# relevance                                                         0.187918
# id                                                                0.050415
# search_term_length                                                0.458113
# product_title_length                                              0.107605
# product_description_length                                        0.158314
# product_title_query_exactmatch                                    0.665800
# product_title_query_match                                         0.647556
# product_description_query_exactmatch                              1.000000
# product_description_query_match                                   0.920982
# door                                                              0.091026
# light                                                             0.045983
# tile                                                              0.065022
# inch                                                              0.007917
# wall                                                              0.044471
# cabinet                                                           0.014613
# shower                                                            0.069744
# wood                                                              0.015626
# white                                                             0.052041
# paint                                                             0.026730
# floor                                                             0.046910
# vaniti                                                            0.057282
# outdoor                                                           0.028141
# water                                                             0.066343
# sink                                                              0.048206
# bathroom                                                          0.026261
# faucet                                                            0.058361
# kitchen                                                           0.048795
# electr                                                            0.016051
# kit                                                               0.030446
# ga                                                                0.041371
# ...                                                                    ...
# stainless                                                         0.071792
# rug                                                              -0.011221
# stone                                                             0.003412
# spray                                                             0.032202
# bath                                                             -0.004560
# 30                                                                0.032075
# plate                                                            -0.001346
# exterior                                                          0.016278
# bolt                                                              0.001463
# hose                                                              0.011766
# doubl                                                             0.046218
# handl                                                             0.015649
# lock                                                             -0.009665
# bar                                                               0.024843
# trim                                                             -0.001096
# valv                                                              0.038079
# blade                                                             0.033336
# screen                                                            0.008408
# dewalt                                                            0.025449
# interior                                                          0.033787
# stove                                                            -0.013141
# garag                                                             0.041743
# mower                                                             0.014707
# garden                                                            0.000618
# ge                                                                0.056618
# closet                                                            0.018882
# water heater                                                      0.119727
# tree                                                              0.001920
# 36                                                                0.048323
# 20                                                                0.008234
#
#                                       product_description_query_match  \
# relevance                                                    0.208070
# id                                                           0.049504
# search_term_length                                           0.481139
# product_title_length                                         0.103353
# product_description_length                                   0.138841
# product_title_query_exactmatch                               0.614469
# product_title_query_match                                    0.673782
# product_description_query_exactmatch                         0.920982
# product_description_query_match                              1.000000
# door                                                         0.102396
# light                                                        0.075043
# tile                                                         0.063649
# inch                                                        -0.000431
# wall                                                         0.052119
# cabinet                                                      0.033856
# shower                                                       0.067633
# wood                                                         0.013097
# white                                                        0.047440
# paint                                                        0.023611
# floor                                                        0.061122
# vaniti                                                       0.057243
# outdoor                                                      0.034938
# water                                                        0.066729
# sink                                                         0.050088
# bathroom                                                     0.042393
# faucet                                                       0.063875
# kitchen                                                      0.057767
# electr                                                       0.022409
# kit                                                          0.032703
# ga                                                           0.039588
# ...                                                               ...
# stainless                                                    0.068740
# rug                                                         -0.002118
# stone                                                        0.003962
# spray                                                        0.026132
# bath                                                         0.001265
# 30                                                           0.025225
# plate                                                        0.009928
# exterior                                                     0.016957
# bolt                                                         0.005505
# hose                                                         0.011539
# doubl                                                        0.049785
# handl                                                        0.021329
# lock                                                         0.005455
# bar                                                          0.025937
# trim                                                         0.000856
# valv                                                         0.038564
# blade                                                        0.038085
# screen                                                       0.017777
# dewalt                                                       0.020662
# interior                                                     0.034933
# stove                                                       -0.019606
# garag                                                        0.052436
# mower                                                        0.020887
# garden                                                       0.002949
# ge                                                           0.047965
# closet                                                       0.027577
# water heater                                                 0.121247
# tree                                                         0.004756
# 36                                                           0.044247
# 20                                                           0.005972
#
#                                           door    ...        stove     garag  \
# relevance                             0.006027    ...    -0.013929 -0.005718
# id                                   -0.005330    ...    -0.018257 -0.016204
# search_term_length                    0.091614    ...     0.000782  0.038640
# product_title_length                  0.082126    ...    -0.007266 -0.001120
# product_description_length            0.063563    ...     0.053052  0.013200
# product_title_query_exactmatch        0.065065    ...    -0.017504  0.009693
# product_title_query_match             0.089693    ...    -0.027274  0.017762
# product_description_query_exactmatch  0.091026    ...    -0.013141  0.041743
# product_description_query_match       0.102396    ...    -0.019606  0.052436
# door                                  1.000000    ...    -0.014878  0.128446
# light                                -0.040762    ...    -0.014894 -0.013820
# tile                                 -0.030884    ...    -0.010050 -0.008856
# inch                                  0.000145    ...     0.006769 -0.009801
# wall                                 -0.027477    ...     0.001024 -0.009849
# cabinet                              -0.007785    ...    -0.009689 -0.009800
# shower                                0.058603    ...    -0.009504 -0.009613
# wood                                 -0.002820    ...     0.013332 -0.003739
# white                                -0.006760    ...    -0.006684 -0.009179
# paint                                -0.022891    ...    -0.008638 -0.008737
# floor                                -0.025638    ...    -0.008343  0.008340
# vaniti                               -0.024157    ...    -0.008160 -0.008253
# outdoor                              -0.025102    ...    -0.008169 -0.008262
# water                                -0.024459    ...    -0.007959 -0.008051
# sink                                 -0.024865    ...    -0.008091 -0.005557
# bathroom                             -0.017721    ...    -0.007943 -0.008034
# faucet                               -0.024076    ...    -0.007835 -0.007925
# kitchen                              -0.014136    ...    -0.007825 -0.007915
# electr                               -0.023599    ...     0.032048 -0.007768
# kit                                  -0.001262    ...    -0.006909 -0.002623
# ga                                   -0.017880    ...     0.048185 -0.007714
# ...                                        ...    ...          ...       ...
# stainless                            -0.010931    ...     0.001238 -0.005333
# rug                                  -0.015141    ...    -0.005281 -0.005342
# stone                                -0.016193    ...    -0.005269 -0.005330
# spray                                -0.014881    ...    -0.005228 -0.005288
# bath                                 -0.011464    ...    -0.005210 -0.005270
# 30                                    0.007192    ...    -0.005174 -0.005233
# plate                                -0.008513    ...    -0.005199 -0.005259
# exterior                              0.042173    ...    -0.005193 -0.005252
# bolt                                 -0.016035    ...    -0.005218 -0.005278
# hose                                 -0.015886    ...    -0.005169 -0.005229
# doubl                                 0.001937    ...     0.024473 -0.005185
# handl                                 0.023511    ...    -0.005110 -0.005169
# lock                                  0.050797    ...    -0.005156 -0.005215
# bar                                   0.003011    ...    -0.005115 -0.001994
# trim                                  0.007803    ...    -0.005110 -0.005169
# valv                                 -0.015765    ...    -0.005130 -0.005189
# blade                                -0.015640    ...    -0.005090 -0.005148
# screen                                0.045927    ...    -0.005101  0.012794
# dewalt                               -0.015197    ...    -0.004945 -0.005002
# interior                              0.122084    ...    -0.004910 -0.004967
# stove                                -0.014878    ...     1.000000 -0.004897
# garag                                 0.128446    ...    -0.004897  1.000000
# mower                                -0.015007    ...    -0.004883 -0.004939
# garden                               -0.008103    ...    -0.004859 -0.004915
# ge                                   -0.003884    ...     0.011027 -0.004864
# closet                                0.048576    ...    -0.004810 -0.004865
# water heater                         -0.014897    ...    -0.004848 -0.004903
# tree                                 -0.014787    ...    -0.004812 -0.004867
# 36                                    0.021902    ...     0.012773 -0.004739
# 20                                   -0.014239    ...     0.009436  0.002712
#
#                                          mower    garden        ge    closet  \
# relevance                             0.006583 -0.007671  0.009849  0.000464
# id                                   -0.029024  0.008327 -0.000207 -0.015678
# search_term_length                    0.015883 -0.011872  0.030338  0.022427
# product_title_length                 -0.005114 -0.012042 -0.004307 -0.010760
# product_description_length            0.055985 -0.004780  0.083180 -0.009351
# product_title_query_exactmatch        0.005767  0.002149  0.057023 -0.013832
# product_title_query_match             0.009224  0.003578  0.048861 -0.003097
# product_description_query_exactmatch  0.014707  0.000618  0.056618  0.018882
# product_description_query_match       0.020887  0.002949  0.047965  0.027577
# door                                 -0.015007 -0.008103 -0.003884  0.048576
# light                                -0.015023 -0.010834 -0.009940 -0.008603
# tile                                 -0.010137 -0.002118 -0.009982 -0.009985
# inch                                 -0.003613 -0.009725 -0.003127 -0.000443
# wall                                 -0.009821 -0.009772 -0.003318 -0.005909
# cabinet                              -0.009773 -0.003831 -0.009624  0.004006
# shower                               -0.009587 -0.009539 -0.009440 -0.009443
# wood                                 -0.009366 -0.009319 -0.003251 -0.000464
# white                                -0.009153 -0.009107 -0.007173  0.014178
# paint                                -0.008712 -0.008669 -0.008579 -0.008582
# floor                                -0.008415 -0.008373 -0.008287 -0.008289
# vaniti                               -0.008231 -0.008189 -0.008105 -0.008107
# outdoor                              -0.008239 -0.007396 -0.008114 -0.008116
# water                                -0.008028 -0.007988  0.015893 -0.007908
# sink                                 -0.008161 -0.007239 -0.002909 -0.008039
# bathroom                             -0.008012 -0.007972 -0.007890 -0.007892
# faucet                               -0.007903 -0.007863 -0.007782 -0.007784
# kitchen                              -0.007893 -0.007853 -0.007772 -0.007774
# electr                                0.031812 -0.007707 -0.004812 -0.007630
# kit                                  -0.007743  0.001052 -0.006031 -0.007626
# ga                                    0.008177 -0.007654 -0.005151 -0.007577
# ...                                        ...       ...       ...       ...
# stainless                            -0.005318 -0.005292  0.017892 -0.005238
# rug                                  -0.005327 -0.005301 -0.005246 -0.005247
# stone                                -0.005315 -0.005289 -0.005234 -0.005235
# spray                                -0.005274 -0.005247 -0.005193 -0.005194
# bath                                 -0.005255 -0.005229 -0.005175 -0.005176
# 30                                   -0.001610 -0.005193  0.013003 -0.005140
# plate                                -0.005244 -0.005218 -0.005164 -0.005166
# exterior                             -0.005238 -0.005211 -0.005158 -0.005159
# bolt                                 -0.005263 -0.005237 -0.005183 -0.005184
# hose                                 -0.005214  0.108644 -0.005135 -0.005136
# doubl                                -0.005171 -0.005145 -0.000879 -0.000254
# handl                                -0.005154 -0.005129 -0.005076 -0.000232
# lock                                 -0.005200 -0.005174 -0.005121 -0.005122
# bar                                  -0.005159 -0.005134 -0.005081 -0.005082
# trim                                 -0.005155 -0.005129 -0.001190 -0.005077
# valv                                 -0.005174  0.010942 -0.005095 -0.005097
# blade                                 0.031917 -0.005108 -0.005055 -0.005057
# screen                               -0.005145 -0.005119 -0.005066 -0.005068
# dewalt                               -0.004988 -0.004963 -0.004912 -0.004913
# interior                             -0.004953 -0.004928 -0.004877  0.013625
# stove                                -0.004883 -0.004859  0.011027 -0.004810
# garag                                -0.004939 -0.004915 -0.004864 -0.004865
# mower                                 1.000000 -0.004901 -0.004850 -0.004852
# garden                               -0.004901  1.000000 -0.004826 -0.004827
# ge                                   -0.004850 -0.004826  1.000000 -0.004778
# closet                               -0.004852 -0.004827 -0.004778  1.000000
# water heater                         -0.004890 -0.004865 -0.002210 -0.004816
# tree                                 -0.004853 -0.004829 -0.004779 -0.004781
# 36                                   -0.004726 -0.004702 -0.004653  0.001047
# 20                                    0.001238 -0.004650 -0.004602 -0.004604
#
#                                       water heater      tree        36  \
# relevance                                 0.021625  0.001924  0.003923
# id                                       -0.036214  0.005757  0.003819
# search_term_length                        0.067411  0.008753  0.081591
# product_title_length                      0.031269  0.008845  0.041767
# product_description_length                0.070999 -0.012337  0.027100
# product_title_query_exactmatch            0.095623  0.012806  0.052201
# product_title_query_match                 0.098996  0.018761  0.051883
# product_description_query_exactmatch      0.119727  0.001920  0.048323
# product_description_query_match           0.121247  0.004756  0.044247
# door                                     -0.014897 -0.014787  0.021902
# light                                    -0.014913 -0.006639 -0.010032
# tile                                     -0.010063 -0.009989 -0.003345
# inch                                     -0.009703 -0.009631  0.050350
# wall                                     -0.009750 -0.009678 -0.005496
# cabinet                                  -0.009702 -0.009630  0.017998
# shower                                   -0.009517 -0.009446  0.032095
# wood                                     -0.009298 -0.009229  0.000519
# white                                    -0.009086 -0.009019  0.032356
# paint                                    -0.008649 -0.008585 -0.008359
# floor                                    -0.008354 -0.008292 -0.000366
# vaniti                                   -0.008171 -0.008110  0.041940
# outdoor                                  -0.001498 -0.008119 -0.000856
# water                                     0.378135 -0.007911 -0.007702
# sink                                     -0.008102 -0.008042  0.009350
# bathroom                                 -0.007954 -0.007895 -0.006775
# faucet                                   -0.007845 -0.007787 -0.007582
# kitchen                                  -0.007835 -0.007777 -0.007572
# electr                                    0.046548 -0.007632 -0.007431
# kit                                       0.001467 -0.007629 -0.001197
# ga                                        0.074222 -0.007580  0.004961
# ...                                            ...       ...       ...
# stainless                                -0.005279 -0.005240  0.009245
# rug                                      -0.005288 -0.005249 -0.005111
# stone                                    -0.005276 -0.005237 -0.005099
# spray                                    -0.005235 -0.005196 -0.005059
# bath                                     -0.005217 -0.005178  0.007346
# 30                                        0.024022 -0.005142 -0.005007
# plate                                    -0.005206 -0.005167 -0.005031
# exterior                                 -0.005199 -0.005161  0.005695
# bolt                                     -0.005225 -0.005186 -0.005049
# hose                                     -0.005176 -0.005138 -0.005003
# doubl                                    -0.005133 -0.005095 -0.004961
# handl                                    -0.005117 -0.005079 -0.004945
# lock                                     -0.005162 -0.005124 -0.004989
# bar                                      -0.005122 -0.005084 -0.004950
# trim                                     -0.005117 -0.005079 -0.004945
# valv                                     -0.001593 -0.005099 -0.004964
# blade                                    -0.005096 -0.005058 -0.004925
# screen                                   -0.005107 -0.005069  0.016880
# dewalt                                   -0.004952 -0.004915 -0.004786
# interior                                 -0.004917 -0.004880  0.007389
# stove                                    -0.004848 -0.004812  0.012773
# garag                                    -0.004903 -0.004867 -0.004739
# mower                                    -0.004890 -0.004853 -0.004726
# garden                                   -0.004865 -0.004829 -0.004702
# ge                                       -0.002210 -0.004779 -0.004653
# closet                                   -0.004816 -0.004781  0.001047
# water heater                              1.000000 -0.004818 -0.004691
# tree                                     -0.004818  1.000000 -0.004656
# 36                                       -0.004691 -0.004656  1.000000
# 20                                       -0.004640 -0.004605 -0.004484
#
#                                             20
# relevance                            -0.010498
# id                                    0.009468
# search_term_length                    0.073324
# product_title_length                 -0.001467
# product_description_length            0.010842
# product_title_query_exactmatch        0.021598
# product_title_query_match             0.020814
# product_description_query_exactmatch  0.008234
# product_description_query_match       0.005972
# door                                 -0.014239
# light                                -0.014254
# tile                                 -0.009619
# inch                                  0.015708
# wall                                 -0.009319
# cabinet                              -0.009273
# shower                               -0.009096
# wood                                 -0.008433
# white                                -0.006968
# paint                                -0.008267
# floor                                -0.000665
# vaniti                               -0.007810
# outdoor                              -0.007818
# water                                -0.007618
# sink                                 -0.007744
# bathroom                             -0.007602
# faucet                               -0.007498
# kitchen                              -0.007489
# electr                                0.011970
# kit                                  -0.007347
# ga                                    0.000346
# ...                                        ...
# stainless                            -0.003713
# rug                                  -0.005055
# stone                                -0.005043
# spray                                -0.005004
# bath                                 -0.004987
# 30                                   -0.000618
# plate                                -0.004976
# exterior                             -0.004970
# bolt                                  0.018389
# hose                                 -0.004948
# doubl                                -0.004906
# handl                                -0.004891
# lock                                 -0.004934
# bar                                   0.017988
# trim                                 -0.004891
# valv                                 -0.004910
# blade                                -0.004871
# screen                               -0.004882
# dewalt                                0.049632
# interior                             -0.004700
# stove                                 0.009436
# garag                                 0.002712
# mower                                 0.001238
# garden                               -0.004650
# ge                                   -0.004602
# closet                               -0.004604
# water heater                         -0.004640
# tree                                 -0.004605
# 36                                   -0.004484
# 20                                    1.000000
#
# [109 rows x 109 columns]

# %%
pearson_corr = train.corr(method='pearson').relevance.sort_values(ascending=False)
pearson_corr[abs(pearson_corr)>0.025]
# Out:
# relevance                               1.000000
# product_title_query_match               0.238750
# product_description_query_match         0.208070
# product_title_query_exactmatch          0.207945
# product_description_query_exactmatch    0.187918
# product_description_length              0.039927
# led                                     0.037260
# sink                                    0.034784
# vaniti                                  0.033169
# light                                   0.031087
# dewalt                                  0.030894
# drill                                   0.028534
# faucet                                  0.027652
# pipe                                   -0.026784
# replac                                 -0.027422
# search_term_length                     -0.072279
# id                                     -0.116426
# Name: relevance, dtype: float64

# %% [markdown]
# ## These are the features with the highest linear correlation to the relevance. Note that,  as oposed to description, the longer the query length, the lower the relevance (should I use just term frequencies rather than tfidf?). Number of word matches are good predictors (note this is univariate)

# %%
spearman_corr = train.corr(method='spearman').relevance.sort_values(ascending=False)
spearman_corr[abs(spearman_corr)>0.03]
# Out:
# relevance                               1.000000
# product_title_query_match               0.226005
# product_title_query_exactmatch          0.197066
# product_description_query_match         0.195245
# product_description_query_exactmatch    0.175472
# product_description_length              0.039546
# led                                     0.035722
# sink                                    0.035172
# light                                   0.034822
# vaniti                                  0.033516
# dewalt                                  0.030962
# pipe                                   -0.030370
# replac                                 -0.030451
# search_term_length                     -0.117370
# id                                     -0.126681
# Name: relevance, dtype: float64

# %%
spearman_corr = train.corr(method='spearman').relevance.sort_values(ascending=False)
spearman_corr
# Out:
# relevance                               1.000000
# product_title_query_match               0.226005
# product_title_query_exactmatch          0.197066
# product_description_query_match         0.195245
# product_description_query_exactmatch    0.175472
# product_description_length              0.039546
# led                                     0.035722
# sink                                    0.035172
# light                                   0.034822
# vaniti                                  0.033516
# dewalt                                  0.030962
# faucet                                  0.029813
# drill                                   0.028578
# bronz                                   0.027144
# heater                                  0.024312
# bathroom                                0.022969
# tile                                    0.020643
# water heater                            0.019969
# fan                                     0.019888
# bulb                                    0.019780
# shower                                  0.019029
# saw                                     0.018958
# set                                     0.018529
# doubl                                   0.016158
# rang                                    0.015875
# ga                                      0.014426
# outdoor                                 0.013775
# toilet                                  0.013286
# rug                                     0.013033
# bath                                    0.012748
#                                           ...
# garag                                  -0.006217
# deck                                   -0.006954
# batteri                                -0.007043
# mount                                  -0.007911
# garden                                 -0.008381
# 20                                     -0.008419
# ft                                     -0.008428
# kit                                    -0.009709
# glass                                  -0.010265
# fenc                                   -0.010711
# round                                  -0.011034
# trim                                   -0.012245
# board                                  -0.012534
# stove                                  -0.012728
# cover                                  -0.014408
# filter                                 -0.014980
# panel                                  -0.015762
# hose                                   -0.016037
# screen                                 -0.017690
# wire                                   -0.018164
# metal                                  -0.018186
# inch                                   -0.018954
# plastic                                -0.020203
# window                                 -0.020696
# product_title_length                   -0.022434
# wood                                   -0.024653
# pipe                                   -0.030370
# replac                                 -0.030451
# search_term_length                     -0.117370
# id                                     -0.126681
# Name: relevance, dtype: float64

# %% [markdown]
# ## Spearman correlation doesn't provide any additional information

# %%
#from pandas import scatter_matrix
best = spearman_corr[abs(spearman_corr)>0.11].index.tolist()
best.remove('id')
best.remove('relevance')
# scatter_matrix(train[best], alpha=0.5, figsize=(100, 50), diagonal='hist');
matplotlib.rc('xtick', labelsize=20);
matplotlib.rc('ytick', labelsize=20);
fig, ax = plt.subplots(figsize=(30, 40), nrows=len(best), ncols=1)
df = train.copy()
for i, col in enumerate(best):
    seaborn.boxplot(df[col], df['relevance'], width=0.5, whis=0.5, fliersize=0, ax=ax[i])
    ax[i].set_xlabel(col, fontsize=25)
    ax[i].set_ylabel('relevance', fontsize=25)
plt.show()

# %% [markdown]
# ## There's an interesting observation here. Search terms with 2 words (25% of the total) give much better results than the average query. As we can see below, only 12% are worse than "relevant" (relevance=2) and 38% are perfect matches. For all search_terms, these number are 16% and 25%, respectively. CHECK if the fraction of matches (number_matches / len(search_term))  is high for 2-word queries!! Let's just add these ratios for now

# %%
train.search_term_length.value_counts(normalize=True)
# Out:
# 3     0.358797
# 2     0.248235
# 4     0.200454
# 5     0.089122
# 1     0.060796
# 6     0.028029
# 7     0.010004
# 8     0.002754
# 9     0.001080
# 11    0.000419
# 10    0.000135
# 12    0.000122
# 14    0.000054
# Name: search_term_length, dtype: float64

# %%
train[train.search_term_length==2].relevance.value_counts(normalize=True)*100
# Out:
# 3.00    37.604699
# 2.67    20.771239
# 2.33    18.329163
# 2.00    11.187860
# 1.67     7.076036
# 1.33     2.828239
# 1.00     2.159252
# 2.50     0.032634
# 2.75     0.005439
# 1.50     0.005439
# Name: relevance, dtype: float64

# %%
# Let's use first these features
common_words = ['door', 'light', 'tile', 'inch', 'wall'] 
corr_words = ['led', 'sink', 'light', 'vaniti'] 
predictors = best + ['product_description_length'] + common_words + corr_words

# %% [markdown]
# ## We are going to use words that very common or that are corrleated with the target variable acording to pearson and spearman

# %%
predictors
# Out:
# ['product_title_query_match',
#  'product_title_query_exactmatch',
#  'product_description_query_match',
#  'product_description_query_exactmatch',
#  'search_term_length',
#  'product_description_length',
#  'door',
#  'light',
#  'tile',
#  'inch',
#  'wall',
#  'led',
#  'sink',
#  'light',
#  'vaniti']

# %%
train, test = train[predictors+['relevance']], test[predictors]

# %%
# Add ratios
def add_ratios(train, test):
    for df in [train, test]:
        for col in best:
            if col != 'search_term_length':
                df[col+"/search_term_length"] = 1. * df[col] / df['search_term_length'] 
                
    return train, test

# %%
train, test = add_ratios(train, test)

# %%
train.columns
# Out:
# Index([                              u'product_title_query_match',
#                                 u'product_title_query_exactmatch',
#                                u'product_description_query_match',
#                           u'product_description_query_exactmatch',
#                                             u'search_term_length',
#                                     u'product_description_length',
#                                                           u'door',
#                                                          u'light',
#                                                           u'tile',
#                                                           u'inch',
#                                                           u'wall',
#                                                            u'led',
#                                                           u'sink',
#                                                          u'light',
#                                                         u'vaniti',
#                                                      u'relevance',
#                   u'product_title_query_match/search_term_length',
#              u'product_title_query_exactmatch/search_term_length',
#             u'product_description_query_match/search_term_length',
#        u'product_description_query_exactmatch/search_term_length'],
#       dtype='object')

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestRegressor as RF
X = train.drop('relevance', axis=1).values
y = train.relevance.values
rf = RF(n_estimators=100, random_state=1, n_jobs=-1)
# 20 features. half of them correlated. 10 presumbly irrelevant
params = {'max_features':[5, 10], 'max_depth':[7, 15]}
rf = GridSearchCV(rf, params,  scoring='mean_squared_error', cv=2, n_jobs=-1, error_score=14., verbose=1)
rf.fit(X, y)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    2.6s remaining:    7.9s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    9.2s finished
# GridSearchCV(cv=2, error_score=14.0,
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=-1, oob_score=False, random_state=1,
#            verbose=0, warm_start=False),
#        fit_params={}, iid=True, loss_func=None, n_jobs=-1,
#        param_grid={'max_features': [5, 10], 'max_depth': [7, 15]},
#        pre_dispatch='2*n_jobs', refit=True, score_func=None,
#        scoring='mean_squared_error', verbose=1)

# %%
print("square-root MSE", np.sqrt(abs(rf.best_score_)))
print("best configuration", rf.best_params_)
# Out:
# ('square-root MSE', 0.49656149776587516)
# ('best configuration', {'max_features': 10, 'max_depth': 7})

# %%
feat_score = list(zip(train.drop('relevance', axis=1).columns, rf.best_estimator_.feature_importances_))
feat_score = sorted(feat_score, key=lambda x: x[1], reverse=True)
print("Feature importances:")
for k in feat_score:
    print(k[0], " = ", 100*round(k[1], 3))
# Out:
# Feature importances:
# ('product_title_query_match/search_term_length', ' = ', 47.3)
# ('product_description_query_match/search_term_length', ' = ', 20.7)
# ('product_title_query_exactmatch/search_term_length', ' = ', 7.7)
# ('product_description_query_exactmatch/search_term_length', ' = ', 6.4)
# ('product_title_query_match', ' = ', 5.3)
# ('search_term_length', ' = ', 3.8)
# ('product_description_length', ' = ', 2.9000000000000004)
# ('product_description_query_match', ' = ', 2.1999999999999997)
# ('product_title_query_exactmatch', ' = ', 1.3)
# ('product_description_query_exactmatch', ' = ', 0.4)
# (u'door', ' = ', 0.4)
# (u'light', ' = ', 0.3)
# (u'light', ' = ', 0.3)
# (u'sink', ' = ', 0.3)
# (u'inch', ' = ', 0.2)
# (u'tile', ' = ', 0.2)
# (u'vaniti', ' = ', 0.1)
# (u'wall', ' = ', 0.1)
# (u'led', ' = ', 0.1)

# %%
from sklearn.metrics import mean_squared_error 
y_pred = rf.predict(X)
train_error = np.sqrt(mean_squared_error(y, y_pred))
print("train_error", train_error)
# Out:
# ('train_error', 0.48663866788160032)

# %%
rf.grid_scores_
# Out:
# [mean: -0.24674, std: 0.00356, params: {'max_features': 5, 'max_depth': 7},
#  mean: -0.24657, std: 0.00349, params: {'max_features': 10, 'max_depth': 7},
#  mean: -0.24979, std: 0.00204, params: {'max_features': 5, 'max_depth': 15},
#  mean: -0.25102, std: 0.00176, params: {'max_features': 10, 'max_depth': 15}]

# %%
train[train.search_term_length==2]["product_title_query_match/search_term_length"].value_counts(normalize=True)
# Out:
# 1.0    0.441151
# 0.5    0.379256
# 0.0    0.178995
# 1.5    0.000598
# Name: product_title_query_match/search_term_length, dtype: float64

# %%
train["product_title_query_match/search_term_length"].value_counts(normalize=True).iloc[:5]
# Out:
# 1.000000    0.233842
# 0.500000    0.175746
# 0.666667    0.170265
# 0.000000    0.125508
# 0.333333    0.097344
# Name: product_title_query_match/search_term_length, dtype: float64

# %% [markdown]
# ## We confirm our earlier hypothesis, namely, search terms containing 2 words match more words in the product title: the 2 words 44% of the times and one of them 38% of the times. 23% and 18% for search terms of any length
